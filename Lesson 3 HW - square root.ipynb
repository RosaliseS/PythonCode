# %% [markdown]
# # Goal
# This project aims to understand how to apply a formula to find the square root of the given
# number.
#
# ## Story
#
# Shiya is facing a lot of problems while calculating the square root. So she wants to design a
# program that will help her find the square root of whatever number she wants. So write a
# program to find the Square root of the number given by the user.

# %%
from math import sqrt

# %%
str_number = input("enter a number: ")

float_num = float(str_number)

print(
    sqrt(float_num)
)
# Out:
# enter a number:  30
# 5.477225575051661

# %%
5.477225575051661 ** 2
# Out:
# 30.0
