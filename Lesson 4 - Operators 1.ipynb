# %%
tree1 = 98 
tree2 = 94
tree3 = 41
tree4 = 95
tree5 = 11

#total
tree_sum = tree1 + tree2 + tree3 + tree4 + tree5
print("the sum of all the trees is:", tree_sum)

#av.
average = tree_sum / 5

print("the average of  all the trees is :", average)
# Out:
# the sum of all the trees is: 339
# the average of  all the trees is : 67.8

# %%
if(average == 100):
    print(":-)")
else:
    print(":-(")
# Out:
# :-(

# %%
51 % 6
# Out:
# 3

# %%
50 % 6
# Out:
# 2

# %%
73 % 8
# Out:
# 1

# %%
115 % 14
# Out:
# 3
