# %%
#activity 1(and)

# %%
a = 10
b = 10
if a > 0 and b > 0:
    print('The numbers are greater than 0!')
# Out:
# The numbers are greater than 0!

# %%
#activity 2(and/or,and)
a = 10
b = 12
c = 0 
if a and b and c:
    print ( 'all the numbers have boolean as True')
else:
    print('At least one number has a boolean value as False')

#or
a = 10
b = -10
c = 0
if a > 0 or b > 0:
    print('At least ONE number is greater than 0 ')
else:
    print("None of your numbers are bigger than 0")
# Out:
# At least one number has a boolean value as False
# At least ONE number is greater than 0
