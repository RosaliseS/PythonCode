# %% [markdown]
# # Congratulations message
#
# ## Goal
# This project aims to get a clear understanding of how to perform operations on a string.
#
# ## Story
# Ram is congratulating his friend for getting a gold medal in the state games. He wrote the
# "Congratulations" in lower case while giving input and now wants to convert it in the upper case.
#
# Write the program for converting the word in upper case.
#
# Best of luck.

# %%
name = input("enter your name :) ")
print(name.upper() , "... congratulations".upper())
# Out:
# enter your name :) masum
# MASUM CONGRATULATIONS
